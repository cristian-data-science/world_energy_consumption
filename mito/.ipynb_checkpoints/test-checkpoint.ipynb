# %%
# Run this cell to render a mitosheet
# See mito's documentation here: https://docs.trymito.io/how-to/creating-a-mitosheet
# Join our Discord for support here: https://discord.gg/XdJSZyejJU

import mitosheet
mitosheet.sheet(analysis_to_replay="id-bzkkdvmugk")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-bsxkpvfkpq", "analysisToReplay": {"analysisName": "id-bzkk…

# %%
from mitosheet import *; register_analysis("id-bzkkdvmugk");
    
# Imported world_energy_consumption.csv
import pandas as pd
world_energy_consumption = pd.read_csv(r'world_energy_consumption.csv')

# Filtered country
world_energy_consumption = world_energy_consumption[world_energy_consumption['country'].apply(lambda val: any(s in str(val) for s in ['Argentina', 'Chile', 'Bolivia', 'Brazil', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Surinam', 'Trinidad and Tobago', 'Uruguay', 'Venezuela']))]

# %%
world_energy_consumption
# Out:
#       iso_code    country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 680        ARG  Argentina  1900                   NaN                   NaN
# 681        ARG  Argentina  1901                   NaN                 0.000
# 682        ARG  Argentina  1902                   NaN                 0.000
# 683        ARG  Argentina  1903                   NaN                 0.000
# 684        ARG  Argentina  1904                   NaN                 0.000
# ...        ...        ...   ...                   ...                   ...
# 16683      VEN  Venezuela  2015                 0.132                 0.009
# 16684      VEN  Venezuela  2016               -49.242                -3.352
# 16685      VEN  Venezuela  2017                -2.473                -0.085
# 16686      VEN  Venezuela  2018               -48.979                -1.650
# 16687      VEN  Venezuela  2019                49.102                 0.844
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 680                    NaN                  NaN                  NaN
# 681                    NaN                0.000                  NaN
# 682                    NaN                0.000                  NaN
# 683                    NaN                0.000                  NaN
# 684                    NaN                0.000                  NaN
# ...                    ...                  ...                  ...
# 16683               13.454               42.768               -2.271
# 16684                3.254               11.737              -10.587
# 16685                3.670               13.667              -11.112
# 16686              -18.097              -69.863              -29.703
# 16687              -16.330              -51.633              -38.349
#
#        oil_prod_change_twh  energy_cons_change_pct  ...  \
# 680                    NaN                     NaN  ...
# 681                  0.000                     NaN  ...
# 682                  0.000                     NaN  ...
# 683                  0.000                     NaN  ...
# 684                  0.000                     NaN  ...
# ...                    ...                     ...  ...
# 16683              -36.531                  -3.519  ...
# 16684             -166.400                  -9.263  ...
# 16685             -156.159                  -4.490  ...
# 16686             -371.043                 -14.049  ...
# 16687             -336.752                  -9.259  ...
#
#        solar_elec_per_capita  solar_energy_per_capita           gdp  \
# 680                      NaN                      NaN  2.311303e+10
# 681                      NaN                      NaN  2.404338e+10
# 682                      NaN                      NaN  2.354418e+10
# 683                      NaN                      NaN  2.693200e+10
# 684                      NaN                      NaN  2.981703e+10
# ...                      ...                      ...           ...
# 16683                  0.233                    0.739  4.830000e+11
# 16684                  0.234                    0.845  3.960000e+11
# 16685                  0.238                    0.851           NaN
# 16686                  0.208                    0.765           NaN
# 16687                  0.210                    1.027           NaN
#
#        wind_share_elec  wind_cons_change_pct  wind_share_energy  \
# 680                NaN                   NaN                NaN
# 681                NaN                   NaN                NaN
# 682                NaN                   NaN                NaN
# 683                NaN                   NaN                NaN
# 684                NaN                   NaN                NaN
# ...                ...                   ...                ...
# 16683            0.060                   NaN              0.000
# 16684            0.068                -100.0              0.000
# 16685            0.071                   NaN              0.000
# 16686            0.073                   NaN              0.000
# 16687            0.080                   NaN              0.059
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 680                     NaN               NaN                   NaN
# 681                     NaN               NaN                   NaN
# 682                     NaN               NaN                   NaN
# 683                     NaN               NaN                   NaN
# 684                     NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 16683                 0.003             0.003                 2.360
# 16684                -0.003             0.000                 2.378
# 16685                 0.000             0.000                 2.415
# 16686                 0.000             0.000                 2.458
# 16687                 0.366             0.366                 2.490
#
#        wind_energy_per_capita
# 680                       NaN
# 681                       NaN
# 682                       NaN
# 683                       NaN
# 684                       NaN
# ...                       ...
# 16683                   0.106
# 16684                   0.000
# 16685                   0.000
# 16686                   0.000
# 16687                  12.840
#
# [1262 rows x 122 columns]
